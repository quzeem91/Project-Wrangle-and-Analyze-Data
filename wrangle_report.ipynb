# %% [markdown]
# ## Data Wrangling -Project Report

# %% [markdown]
# This report details how  the WeRateDogs Twitter data ( the tweet archive of Twitter user **@dog_rates**, also known as **WeRateDogs.**)was wrangled to create interesting and trustworthy analyses and visualizations.The WeRateDogs is a Twitter account that rates people's dogs with a humorous comment about the dog. <br>
# For this project three  Dataset were used whilst being provided with two(a csv file and a url link to download a tsv file)  ,which are ;<br>
#     1. WeRateDogs Twitter_archive Data which contains information such as(tweet_id,timestamp,rating_numerator,
#     rating_denominator,name etc) and
#     2. a tab seperated values file containing images to be filtered for the pics of dogs

# %% [markdown]
# ### Loading The Datasets Into The Project Environment

# %% [markdown]
# **The "twitter_archive-enhanced.csv" file was downloaded from this provided
# <a href="https://d17h27t6h515a5.cloudfront.net/topher/2017/August/59a4e958_twitter-archive-enhanced/twitter-archive-enhanced.csv"> link</a> and uploaded to the project workspace enviromnment and The Python Request Library was used To Download the image_predictions tsv**

# %% [markdown]
# ![Screenshot%20%28124%29.png](attachment:Screenshot%20%28124%29.png)

# %% [markdown]
#                 While the WeRateDogs Twitter Archive Data contained some interesting columns ,Two vital Variables pertaining to the analysis were left out(Likes and retweets).To get the likes and retweets of each tweet_id in the WeRateDogs  twitter archivedata,It will be  required to query Twitter API for these two Variables.to be derived for a twitter Developer Account to be Created

# %% [markdown]
# ###  *Querying Twitter's API*
#     To Query Twitter's API for The Likes and Retweets Variables ,A Twitter developer account is to be created (prerequiste,one needs to have a twitter account)amongst other steps .After Succesfully signing up for a Developer Account,a mail was written to twitter support system requesting for an Elevated access to their API and explaining how Data will be        queried and used .

# %% [markdown]
# **Confirmation of The Request Mail being Received**
# ![Screenshot%20%28109%29.png](attachment:Screenshot%20%28109%29.png)

# %% [markdown]
#       After The confirmation Email to the Request being acknowledged ,Another mail was  required to be sent Explaining
#      in Details How Twitter Data will be used and How Data privacy rules will be respected and not violated.Then an approval Email for the  Elevated Access request was granted

# %% [markdown]
# ![Screenshot%20%28111%29.png](attachment:Screenshot%20%28111%29.png)

# %% [markdown]
#     With the Elevated Acces being Granted , Authorization And Consumere Tokens were generated

# %% [markdown]
# ![Screenshot%20%28112%29.png](attachment:Screenshot%20%28112%29.png)

# %% [markdown]
#       An API object was Created To Gather The Likes and Retweets associated with each Tweet_id in the Twitter_archive Data.A config_file was created to store and protect the  generated tokens from possible Data Breach.Through this config_file    the  access tokens were safely imported to the wrangling_act.ipynb file and used in  creating an API object to gather the required data.

# %% [markdown]
# ![Screenshot%20%28114%29.png](attachment:Screenshot%20%28114%29.png)

# %% [markdown]
#     Using the tweet_id in the WeRateDogs Twitter Archive Data,the json Data of each tweet_id was written to a tweet_json.txt file ,where  the tweet_id ,likes and retweets were appended to a list (df_lists) ,which was converted to a Dataframe(df_json) with the help of Pandas and Numpy library.It is to be noted that few tweet_ids gave error during the querying as a  result of them being deleted and were all appended to a list.

# %% [markdown]
# ![Screenshot%20%28117%29.png](attachment:Screenshot%20%28117%29.png)

# %% [markdown]
#     A df_list(List Data Structure) variable was created to dump the required json data and a Dataframe(df_json) was created From it

# %% [markdown]
# ![Screenshot%20%28122%29.png](attachment:Screenshot%20%28122%29.png)

# %% [markdown]
# ### *Visual And Programmatic Assessment*

# %%
Now

# %%
Then the visual and programmatic Assessment approaches were both taken(Prior to this  ,all Datasets have been loaded into the work environment) were Quality and Tidiness Issues were detected and documented . <br>
The Define,Code and Test approach was employed in the data cleaning  phase of the project and it was iterative .New columns were extracted/calculated such as the (Day,month ,year columns from the timestamp column ) and also few columns that werent pivotal to the analysis were dropped.Then analyses and visualizations were carried out and insights were made.
